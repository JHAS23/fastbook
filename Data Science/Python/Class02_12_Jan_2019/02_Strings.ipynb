# %% [markdown]
# # String

# %%
a = "String1"
b = "String2"
c = "String3"
d = "Str'i'ng1"
e = 'Str"i"ng1'
f = """Str"i"ng1'"""

# %%
print(a,"\n","\n",b,c)
# Out:
# String1
#
#  String2 String3

# %%
tmp = "0123456789"
len(tmp)
# Out:
# 10

# %%
# print(tmp[0]) # Indexing
# print(tmp[4]) 
# print(tmp[:4]) # Slicing
# print(tmp[:])
# print(tmp[2:])
# print(tmp[-1])
# print(tmp[-5:])
# print(tmp[:-6])
# print(tmp[-1:-6])
# print(tmp[-6:-1])
# print(tmp[::-1])
# print(tmp[::2])
# print(tmp[::5])
# Out:
# 02468

# %% [markdown]
# # Create a string of 0-9 and filter out all even and odd substring

# %%
print(tmp[::2])
print(tmp[1::2])
# Out:
# 02468
# 13579

# %%
_
# Out:
# '13579'

# %%
dir(tmp)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
a = "this is string 11111"
a.capitalize()
# Out:
# 'This is string 11111'

# %%
a.upper()
# Out:
# 'THIS IS STRING 11111'

# %%
a.count("1")
# Out:
# 5

# %%
a.count("s")
# Out:
# 3

# %%
a.title()
# Out:
# 'This Is String 11111'

# %%
print("test1")
print("#"*50)
print("test2")
# Out:
# test1
# ##################################################
# test2
