# %% [markdown]
# # Operators

# %% [markdown]
# #### Python Assignment Operators and Arithmetic Operators

# %%
a = 10
b = 2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b) # Floor division
print(a**b)
print(10%3)
# Out:
# 12
# 8
# 20
# 5.0
# 5
# 100
# 1

# %% [markdown]
# #### Comparison Operators

# %%
a = 2
b = 3
print (a==b)
print (a is 2)
print (a is not  3)
# Out:
# False
# True
# True

# %%
print(a is 3)
# Out:
# False

# %%
a=2
b=1
c=0
d=5
e=7
# print(c or b or a is d)
print(c or b and a is d)
print(c or False)
# Out:
# False
# False

# %% [markdown]
# #### Logical Operators

# %%
a = 1
b = 2
c = 0
d = 11
e = .2
print(a and b and c and e and a and d)
# Out:
# 0

# %%
a = 1
b = 2
c = 0
d = 11
e = .2
print(c or d)
print(a or c and d)
print(a and c or d)
# Out:
# 11
# 1
# 11

# %% [markdown]
# #### Membership Operators

# %%
a = [1,2,3,4,5]
print(2 in a)
print(20 not in a)
print(20 in a)
# Out:
# True
# True
# False

# %% [markdown]
# # Operators (Decreasing order of precedence) 	Meaning
# ** 	Exponent
# *, /, //, % 	Multiplication, Division, Floor division, Modulus
# +, - 	Addition, Subtraction
# <= < > >= 	Comparison operators
# = %= /= //= -= += *= **= 	Assignment Operators
# is is not 	Identity operators
# in not in 	Membership operators
# not or and 	Logical operators
# and, is , or

# %% [markdown]
# # Getting input from user

# %%
a = input("Please enter some number...")
print("User entered::",a)
# Out:
# Please enter some number...2
# User entered:: 2

# %% [markdown]
# # Comments and Multiline comments

# %%
# This is single line comment_1
# This is single line comment_2 \
"""This is multi line comment1
This is multi line comment2
This is multi line comment3
"""
# Out:
# 'This is multi line comment1\nThis is multi line comment2\nThis is multi line comment3\n'
