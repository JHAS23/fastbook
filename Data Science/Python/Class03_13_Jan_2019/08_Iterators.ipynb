# %% [markdown]
# # Iterators

# %%
a = [1,2,3,4,5]

# %%
itr_obj = iter(a) # To create iterator object using iter function

# %%
itr_obj # Iter Obj at some mem location

# %%
next(itr_obj)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-12-660dc764787f> in <module>()
# ----> 1 next(itr_obj)
#
# StopIteration:

# %% [markdown]
# # iter obj using comprehnesion style

# %%
itr_obj2 = (var for var in range(5))
print(itr_obj2)
# Out:
# <generator object <genexpr> at 0x0000028E15F9E620>

# %%
next(itr_obj2)
# Out:
# 1
