# %% [markdown]
# # Dictionary

# %%
a = {}
print(a)
print(type(a))
# Out:
# {}
# <class 'dict'>

# %%
b = {"A":1,"B":2}
c = {"A":1,"A":2}
d = {100:1,"A":2}
e = {10.4:1,"A":2}
f = {(1,2,3):1,"A":2}
g = {"a":1,"A":2}
# h = {{"A":1}:1,"A":2}
i = {"A":1,"B":{"D":100,"E":200}}
# j = {[1,2]:1,"A":2}

# %%
print(a)
print(b)
print(c)
print(e)
print(d)
print(e)
print(f)
print(g)
print(i)
# Out:
# {}
# {'A': 1, 'B': 2}
# {'A': 2}
# {10.4: 1, 'A': 2}
# {100: 1, 'A': 2}
# {10.4: 1, 'A': 2}
# {(1, 2, 3): 1, 'A': 2}
# {'a': 1, 'A': 2}
# {'A': 1, 'B': {'D': 100, 'E': 200}}

# %%
d2 = {"A":1,"B":2,"C":3,"D":4}

# %%
d2["A"]
# Out:
# 1

# %%
d2["C"]
# Out:
# 3

# %%
d2["E"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-cfe4dded724d> in <module>()
# ----> 1 d2["E"]
#
# KeyError: 'E'

# %%
d2["Z"] = 20 # Will add new K:V pair in original dictionary
print(d2)
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'Z': 20}

# %%
d2["Z"] = 200
print(d2)
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'Z': 200}

# %%
d2.keys() # Will return struct of dict keys
# Out:
# dict_keys(['A', 'B', 'C', 'D', 'Z'])

# %%
keys = d2.keys()
list(keys)[1] # Will convert whole struct to normal list
# Out:
# 'B'

# %%
d2.values()
# Out:
# dict_values([1, 2, 3, 4, 20])

# %%
# dir(d2)

# %%
d2.pop("D")
# Out:
# 4

# %%
d2
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'Z': 20}

# %%
list(d2.items())[0]
# Out:
# ('A', 1)

# %%
tmp = {'A': 1, 'B': {'D': 100, 'E': 200}}
tmp.items()
# Out:
# dict_items([('A', 1), ('B', {'D': 100, 'E': 200})])

# %%
tmp2 = {'A': 1, 'B': {'D': 100, 'E': 200,"F":"A"}}
# tmp2[tmp2["B"]["F"]]
tmp2[tmp2["B"]["F"]]
# Out:
# 1

# %%
tmp2
# Out:
# {'A': 1, 'B': {'D': 100, 'E': 200, 'F': 'A'}}

# %%
del tmp2["A"]

# %%
tmp2
# Out:
# {'B': {'D': 100, 'E': 200, 'F': 'A'}}
