# %% [markdown]
# # Tuple

# %%
a = ()

# %%
print(a)
# Out:
# ()

# %%
type(a)
# Out:
# tuple

# %%
b = (1,) # Single element should end with ","

# %%
print(b)
# Out:
# (1,)

# %%
c = (1,2,3,4)

# %%
print(c)
# Out:
# (1, 2, 3, 4)

# %%
c.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b8a599b53150> in <module>()
# ----> 1 c.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
c[0]
# Out:
# 1

# %%
c[::-1]
# Out:
# (4, 3, 2, 1)

# %%
del c # Can be used to delete any variables

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2cd6ee2c70b0> in <module>()
# ----> 1 c
#
# NameError: name 'c' is not defined
